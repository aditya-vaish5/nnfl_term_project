# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-vaish5/nnfl_term_project/blob/master/nnfl_termproject__lstm_working_30_min_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/train.en
# !wget https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/train.vi
# !wget https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/tst2013.en
# !wget https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/tst2013.vi
# Out:
# --2020-05-24 14:04:32--  https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/train.en
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13603614 (13M) [text/plain]
# Saving to: ‘train.en’
#
# train.en            100%[===================>]  12.97M  3.40MB/s    in 3.8s
#
# 2020-05-24 14:04:37 (3.40 MB/s) - ‘train.en’ saved [13603614/13603614]
#
# --2020-05-24 14:04:44--  https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/train.vi
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18074646 (17M) [text/plain]
# Saving to: ‘train.vi’
#
# train.vi            100%[===================>]  17.24M  4.35MB/s    in 4.0s
#
# 2020-05-24 14:04:49 (4.35 MB/s) - ‘train.vi’ saved [18074646/18074646]

# %%
import numpy as np
import csv
import torch
import torch.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import unicodedata
import re
import time

# %%
sentences_to_read = 140000

# %%
source_sent = []
target_sent = []

test_source_sent = []
test_target_sent = []


with open('train.en', encoding='utf-8') as f:
    for l_i, line in enumerate(f):
        # discarding first 20 translations as there was some
        # english to english translations found in the first few. which are wrong
        if l_i<50:
            continue
        source_sent.append(line)
        if len(source_sent)>=sentences_to_read:
            break
        
            
with open('train.vi', encoding='utf-8') as f:
    for l_i, line in enumerate(f):
        if l_i<50:
            continue
        
        target_sent.append(line)
        if len(target_sent)>=sentences_to_read:
            break
        
            
assert len(source_sent)==len(target_sent),'Source: %d, Target: %d'%(len(source_sent),len(target_sent))

print('Sample translations (%d)'%len(source_sent))
for i in range(0,sentences_to_read,10000):
    print('(',i,') EN: ', source_sent[i])
    print('(',i,') VI: ', target_sent[i])
# Out:
# Sample translations (133267)
# ( 0 ) EN:  In each one of those assessments that we write , we always tag on a summary , and the summary is written for a non-scientific audience .
#
# ( 0 ) VI:  Trong mỗi bản đánh giá chúng tôi viết , chúng tôi luôn đính kèm một bản tóm lược , được viết cho những độc giả không chuyên về khoa học .
#
# ( 10000 ) EN:  This is an area in the prefrontal cortex , a region where we can use cognition to try to overcome aversive emotional states .
#
# ( 10000 ) VI:  Đây là một khu vực trong vỏ não trước trán , vùng mà chúng sử dụng tri thức cho việc thử vượt qua trạng thái cảm xúc ác cảm .
#
# ( 20000 ) EN:  And there are flowers that are self-infertile . That means they can &apos;t -- the pollen in their bloom can &apos;t fertilize themselves .
#
# ( 20000 ) VI:  có những loài hoa không thể tự thụ phấn . Nghĩa là chúng không thể -- phấn hoa của nó không thể tụ thụ phấn được
#
# ( 30000 ) EN:  And a lot of this comes together in a philosophy of change that I find really is powerful .
#
# ( 30000 ) VI:  Và nhiều như vậy hợp lại thành một triết lý của sự thay đổi mà tôi thấy là thực sự rất mạnh .
#
# ( 40000 ) EN:  Dean Ornish : At first for a long time , I wrote messages in notebooks .
#
# ( 40000 ) VI:  Dean Ornish : &quot; Trong một khoảng thời gian dài ban đầu , tôi đã viết các tin nhắn trên các cuốn ghi chú .
#
# ( 50000 ) EN:  World &apos;s first bamboo bike with folding handlebars .
#
# ( 50000 ) VI:  Chiếc xe đạp bằng tre đầu tiên trên thế giới với ghi đông gập .
#
# ( 60000 ) EN:  We need to invest more resources into research and treatment of mental illness .
#
# ( 60000 ) VI:  Chúng ta cần đầu tư nhiều nguồn lực hơn cho công cuộc nghiên cứu và chữa trị về bệnh thần kinh .
#
# ( 70000 ) EN:  If we are providing knowledge and experience , we need to structure that .
#
# ( 70000 ) VI:  Nếu chúng ta cung cấp kiến thức và kinh nghiệm , chúng ta cần cơ cấu nó .
#
# ( 80000 ) EN:  But I say it has to be under the conditions I &apos;ve always worked : no credit , no logos , no sponsoring .
#
# ( 80000 ) VI:  Nhưng tôi nói nó phải theo các điều kiện tôi luôn luôn làm không có tín dụng , không có biểu tượng , không có tài trợ .
#
# ( 90000 ) EN:  What would it look like ?
#
# ( 90000 ) VI:  Nó sẽ trông như thế nào ?
#
# ( 100000 ) EN:  And the 70 year-old ones , actually they &apos;re better at scouting out the good nesting places , and they also have more progeny every year .
#
# ( 100000 ) VI:  Và những con 70 tuổi , thực sự giỏi hơn trong việc tìm kiếm một nơi để dựng tổ , và chúng cũng có nhiều con hơn hàng năm
#
# ( 110000 ) EN:  The next time you dine on sushi -- or sashimi , or swordfish steak , or shrimp cocktail , whatever wildlife you happen to enjoy from the ocean -- think of the real cost .
#
# ( 110000 ) VI:  Khi bạn thưởng thức sushi , hay sashimi , hay thịt cá kiếm nướng , hay cốc-tai tôm , bất kể thứ gì hoang dã từ đại dương mà bạn thưởng thức , hãy nghĩ về cái giá thực sự phải trả .
#
# ( 120000 ) EN:  When I laid out my plan , I realized that I faced three main challenges : first , creating a sensor ; second , designing a circuit ; and third , coding a smartphone app .
#
# ( 120000 ) VI:  Khi lập kế hoạch , tôi nhận ra mình đối mặt với 3 thách thức : thứ nhất , tạo ra một cảm biến ; thứ hai , thiết kế bảng mạch ; thứ ba , lập trình ứng dụng .
#
# ( 130000 ) EN:  Why would you do something that dangerous ?
#
# ( 130000 ) VI:  Tại sao bạn lại sẵn sàng làm một việc nguy hiểm như thế ?

# %%
# import re
# from collections import Counter

# with open('train.en') as f:
#     passage = f.read()

# words = re.findall(r'\S+', passage)

# cap_words = [word.upper() for word in words]

# word_counts = Counter(cap_words)

# %%
# # for i in range(0,len(word_counts),10000):
# print(word_counts)

# %%
# len(cap_words)

# %%
# from collections import OrderedDict
# sorted_train_eng = OrderedDict(sorted(word_counts.items(), key = lambda kv : kv[1], reverse=True))

# %%
# sorted_train_eng=list(sorted_train_eng)

# %%
# len(sorted_train_eng)

# %%
# sorted_train_engg=sorted_train_eng[0:100000]

# %%
# len(sorted_train_eng)

# %%
# print(sorted_train_engg)

# %%
# import re
# from collections import Counter

# with open('train.vi') as f:
#     passage = f.read()

# words = re.findall(r'\S+', passage)

# cap_words = [word.upper() for word in words]

# word_counts_vi = Counter(cap_words)

# %%
# from collections import OrderedDict
# sorted_train_vi = OrderedDict(sorted(word_counts_vi.items(), key = lambda kv : kv[1], reverse=True))

# %%
# sorted_train_vii=list(sorted_train_vi)

# %%
# len(sorted_train_vii)

# %%
# !wget https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/vocab.vi

# %%
# with open('vocab.vi') as f:
#     passage4 = f.read()

# %%
# passage4

# %%
#

# %%
# import re

# words_vi = re.findall(r'\S+', passage4)
# words_vi[-3]

# %%
# len(words4)

# %%
# !wget https://nlp.stanford.edu/projects/nmt/data/wmt14.en-de/vocab.50K.en

# %%
# with open('vocab.50K.en') as f:
#     passage3 = f.read()
# words_en = re.findall(r'\S+', passage3)
# len(words3)

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip

# %%
# # !apt install gzip
# # import gzip
# # with gzip.open('/content/glove.6B.txt.gz') as f:
# #   glove_vec = f.read()
# !unzip glove*.zip

# %%
# !ls

# %%
# f = open('glove.6B.50d.txt', encoding= 'utf-8')

# %%
# dic = {}
# for line in f:
#   v = line.split()
#   word = v[0]
#   vec = np.asarray(v[1:],dtype = 'float32')
#   dic[word] = vec
# f.close()

# %%
# print(len(dic))

# %%
# glove_dic =  OrderedDict(dic.items())

# %%
# # for i in range(0, len(glove_dic) ,10000):
#   print(glove_dic[i])

# %%
# import itertools

# %%
# x = itertools.islice(dic.items(), 0, len(dic),40000)

# for key, value in x:
#   print (key, value)

# %%
# len(words3)

# %%
# from scipy import spatial

# %%
# def return_embedding_for_eng_word(dic,word):
#   try:
#     x = dic[word]
#     return x
#   except KeyError:
#     return np.random.normal(0,2,50)

# %%
# eng_dict = {};
# for w in sorted:
#   eng_dict[w] = return_embedding_for_eng_word(dic,w)

# %%
# eng_vects = itertools.islice(eng_dict.items(), 0, len(eng_dict),10000)

# for key, value in eng_vects:
#   print (key, value)

# %%
# print(len(eng_dict))

# %%
# def return_embedding_for_vietnamese_word():
#   return np.random.normal(0,2,50)

# %%
# print(len(words4))

# %%
# viet_dict = {}
# for w in words4:
#   viet_dict[w] = return_embedding_for_vietnamese_word()

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
# Turn a Unicode string to plain ASCII, thanks to
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %%
MAX_LENGTH = 20

# eng_prefixes = (
#     "i am ", "i m ",
#     "he is", "he s ",
#     "she is", "she s ",
#     "you are", "you re ",
#     "we are", "we re ",
#     "they are", "they re "
# )


def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH 
        # and \
        # p[1].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2):
    input_lang = Lang(lang1)
    output_lang = Lang(lang2)
    pairs = [];
    for i in range(0,len(target_sent)):
      pairs.append([normalizeString(source_sent[i]) ,normalizeString(target_sent[i])])
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

# %%
input_lang, output_lang, pairs = prepareData('eng', 'vi')
print(random.choice(pairs))
# Out:
# Read 133267 sentence pairs
# Trimmed to 66499 sentence pairs
# Counting words...
# Counted words:
# eng 23610
# vi 7837
# ['i said quot do you pray ? quot ', 'toi hoi lai quot cac ban co cau nguyen khong ? quot ']

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        # self.input_size = input_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, bidirectional = True)



    def forward(self, input, hidden, cell_state):
        # print("forward running")
        # print(self.embedding(input).size())
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        # print(output.size())
        # output, (hidden, cell_state) = self.lstm(output)
        output, (hidden, cell_state) = self.lstm(output, (hidden, cell_state))
        # print(output.size())
        return output, hidden, cell_state

    def initHidden(self):
        return torch.zeros(2, 1, self.hidden_size, device = device)
    def initcellstate(self):
      return torch.zeros(2, 1, self.hidden_size, device = device)

# %%
# THIS CLASS ISN'T USED IN EVALUATION
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
MAX_LENGTH = 20
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 3, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.lstm = nn.LSTM(self.hidden_size, self.hidden_size,bidirectional =True)
        self.out = nn.Linear(self.hidden_size*2, self.output_size)

    def forward(self, input, hidden, cell_state, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        # print(attn_weights.unsqueeze(0).size(), encoder_outputs.unsqueeze(0).size())
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))
        # print(embedded[0].size(),attn_applied[0].size())
        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, (hidden, cell_state) = self.lstm(output, (hidden, cell_state))

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, cell_state, attn_weights

    def initHidden(self):
        return torch.zeros(2, 1, self.hidden_size, device = device)
    def initcellstate(self):
        return torch.zeros(1, 1, self.hidden_size, device = device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()
    encoder_cell = encoder.initcellstate()
    # print("setting optimizers to zero grad")
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    # print("INPUT SIZE: ", input_tensor.size())
    encoder_outputs = torch.zeros(max_length, encoder.hidden_size*2, device=device)

    loss = 0

    for ei in range(input_length):
      # print("starting encoder for " , ei)
      encoder_output, encoder_hidden, encoder_cell = encoder(
          input_tensor[ei], encoder_hidden, encoder_cell)
      # print(encoder_output)
      encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden
    decoder_cell = encoder_cell
    for di in range(target_length):
      # print("decoder for di : ", di)
      decoder_output, decoder_hidden, decoder_cell, decoder_attention = decoder(
          decoder_input, decoder_hidden, decoder_cell, encoder_outputs)
      topv, topi = decoder_output.topk(1)
      decoder_input = topi.squeeze().detach()  # detach from history as input

      loss += criterion(decoder_output, target_tensor[di])
      if decoder_input.item() == EOS_token:
          break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)

    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    # print("train Iter optimizers set")
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    # print("training pairs for this iteration have been assigned")
    # print("training pairs size")
    # print(len(training_pairs))
    # print(len(training_pairs[0]))
    # print(len(training_pairs[0][0]))
    # print(len(training_pairs[0][0]))
    # print(training_pairs[0][0])
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        # print(iter , " : printing iter-1 th training pair")
        # print(training_pair)
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]
        # print(iter , " : started training with above tensors")

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        # print(iter," : current iter ended");
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
hidden_size = 100
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
print("Encoder initialization done")
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
print("Decoder initialization done")

# trainIters(encoder1, attn_decoder1, 75000, print_every=5000)
trainIters(encoder1, attn_decoder1, 50000, print_every=500)
# Out:
# Encoder initialization done
# Decoder initialization done
# 0m 22s (- 36m 57s) (500 1%) 3.0556
# 0m 40s (- 33m 5s) (1000 2%) 3.2432
# 0m 59s (- 32m 8s) (1500 3%) 3.2670
# 1m 20s (- 32m 3s) (2000 4%) 3.5236
# 1m 39s (- 31m 26s) (2500 5%) 3.2013
# 2m 0s (- 31m 23s) (3000 6%) 3.4493
# 2m 21s (- 31m 19s) (3500 7%) 3.5711
# 2m 41s (- 31m 1s) (4000 8%) 3.4845
# 3m 1s (- 30m 39s) (4500 9%) 3.4166
# 3m 21s (- 30m 15s) (5000 10%) 3.3206
# 3m 43s (- 30m 5s) (5500 11%) 3.4826
# 4m 4s (- 29m 50s) (6000 12%) 3.5004
# 4m 26s (- 29m 40s) (6500 13%) 3.7311
# 4m 47s (- 29m 28s) (7000 14%) 3.8593
# 5m 11s (- 29m 23s) (7500 15%) 4.2150
# 5m 36s (- 29m 25s) (8000 16%) 4.4940
# 6m 0s (- 29m 19s) (8500 17%) 4.2089
# 6m 24s (- 29m 13s) (9000 18%) 4.3232
# 6m 48s (- 29m 3s) (9500 19%) 4.2971
# 7m 14s (- 28m 59s) (10000 20%) 4.5427
# 7m 39s (- 28m 48s) (10500 21%) 4.3937
# 8m 4s (- 28m 37s) (11000 22%) 4.4538
# 8m 29s (- 28m 27s) (11500 23%) 4.5321
# 8m 54s (- 28m 12s) (12000 24%) 4.3344
# 9m 20s (- 28m 0s) (12500 25%) 4.5423
# 9m 45s (- 27m 47s) (13000 26%) 4.5125
# 10m 11s (- 27m 32s) (13500 27%) 4.4561
# 10m 36s (- 27m 15s) (14000 28%) 4.4335
# 11m 1s (- 26m 58s) (14500 28%) 4.4057
# 11m 26s (- 26m 40s) (15000 30%) 4.4296
# 11m 51s (- 26m 23s) (15500 31%) 4.4038
# 12m 17s (- 26m 7s) (16000 32%) 4.6329
# 12m 43s (- 25m 49s) (16500 33%) 4.4023
# 13m 8s (- 25m 30s) (17000 34%) 4.2987
# 13m 33s (- 25m 10s) (17500 35%) 4.4186
# 13m 58s (- 24m 51s) (18000 36%) 4.4204
# 14m 24s (- 24m 31s) (18500 37%) 4.4323
# 14m 49s (- 24m 12s) (19000 38%) 4.4210
# 15m 15s (- 23m 52s) (19500 39%) 4.4037
# 15m 40s (- 23m 30s) (20000 40%) 4.1500
# 16m 6s (- 23m 10s) (20500 41%) 4.2932
# 16m 32s (- 22m 50s) (21000 42%) 4.3797
# 16m 56s (- 22m 27s) (21500 43%) 4.0987
# 17m 22s (- 22m 6s) (22000 44%) 4.2553
# 17m 48s (- 21m 45s) (22500 45%) 4.3785
# 18m 13s (- 21m 23s) (23000 46%) 4.2363
# 18m 38s (- 21m 1s) (23500 47%) 4.1968
# 19m 3s (- 20m 39s) (24000 48%) 4.3370
# 19m 29s (- 20m 17s) (24500 49%) 4.3309
# 19m 54s (- 19m 54s) (25000 50%) 4.1304
# 20m 19s (- 19m 31s) (25500 51%) 4.1601
# 20m 44s (- 19m 8s) (26000 52%) 4.1493
# 21m 9s (- 18m 46s) (26500 53%) 4.3271
# 21m 35s (- 18m 23s) (27000 54%) 4.2881
# 22m 0s (- 18m 0s) (27500 55%) 4.1018
# 22m 25s (- 17m 37s) (28000 56%) 4.2828
# 22m 51s (- 17m 14s) (28500 56%) 4.3696
# 23m 16s (- 16m 51s) (29000 57%) 4.2613
# 23m 41s (- 16m 28s) (29500 59%) 4.1899
# 24m 7s (- 16m 5s) (30000 60%) 4.3955
# 24m 33s (- 15m 41s) (30500 61%) 4.1959
# 24m 58s (- 15m 18s) (31000 62%) 4.3303
# 25m 24s (- 14m 55s) (31500 63%) 4.2466
# 25m 49s (- 14m 31s) (32000 64%) 4.1216
# 26m 14s (- 14m 7s) (32500 65%) 4.1678
# 26m 40s (- 13m 44s) (33000 66%) 4.3141
# 27m 5s (- 13m 20s) (33500 67%) 4.2186
# 27m 30s (- 12m 56s) (34000 68%) 4.1568
# 27m 55s (- 12m 32s) (34500 69%) 4.0827
# 28m 20s (- 12m 8s) (35000 70%) 4.1653
# 28m 45s (- 11m 44s) (35500 71%) 4.0997
# 29m 11s (- 11m 21s) (36000 72%) 4.2654
# 29m 37s (- 10m 57s) (36500 73%) 4.3111
# 30m 2s (- 10m 33s) (37000 74%) 4.2442
# 30m 27s (- 10m 9s) (37500 75%) 4.1270
# 30m 53s (- 9m 45s) (38000 76%) 4.2421
# 31m 18s (- 9m 21s) (38500 77%) 4.1039
# 31m 43s (- 8m 56s) (39000 78%) 4.1491
# 32m 8s (- 8m 32s) (39500 79%) 4.2912
# 32m 34s (- 8m 8s) (40000 80%) 4.2924
# 33m 0s (- 7m 44s) (40500 81%) 4.3042
# 33m 26s (- 7m 20s) (41000 82%) 4.2149
# 33m 52s (- 6m 56s) (41500 83%) 4.2799
# 34m 18s (- 6m 32s) (42000 84%) 4.2157
# 34m 44s (- 6m 7s) (42500 85%) 4.2281
# 35m 11s (- 5m 43s) (43000 86%) 4.4336
# 35m 38s (- 5m 19s) (43500 87%) 4.2992
# 36m 4s (- 4m 55s) (44000 88%) 4.3408
# 36m 30s (- 4m 30s) (44500 89%) 4.1645
# 36m 56s (- 4m 6s) (45000 90%) 4.1963
# 37m 21s (- 3m 41s) (45500 91%) 4.1263
# 37m 47s (- 3m 17s) (46000 92%) 4.2503
# 38m 12s (- 2m 52s) (46500 93%) 4.2578
# 38m 38s (- 2m 28s) (47000 94%) 4.2578
# 39m 4s (- 2m 3s) (47500 95%) 4.3416
# 39m 30s (- 1m 38s) (48000 96%) 4.2273
# 39m 57s (- 1m 14s) (48500 97%) 4.2812
# 40m 23s (- 0m 49s) (49000 98%) 4.1203
# 40m 49s (- 0m 24s) (49500 99%) 4.2754
# 41m 15s (- 0m 0s) (50000 100%) 4.1317

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()
        encoder_cell = encoder.initcellstate()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size*2, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden,encoder_cell = encoder(input_tensor[ei],
                                                     encoder_hidden,encoder_cell)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden
        decoder_cell = encoder_cell
        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden,decoder_cell, decoder_attention = decoder(
                decoder_input, decoder_hidden,decoder_cell, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=1000):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
print(input_lang.n_words)
# Out:
# 23610

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# > or this ?
# = hoac mau tin nay ?
# < hay ieu nay ? <EOS>
#
# > sj excellent thank you .
# = sj tuyet voi cam on anh .
# < cam on . . . . <EOS>
#
# > so i wanted to become a teacher .
# = the nen toi muon lam mot co giao .
# < vi toi toi toi mot mot mot . . <EOS>
#
# > and well i didn apos t expect them to even answer my email .
# = va o toi con chang mong oi gi la ho se tra loi thu .
# < va toi toi khong khong khong khong . . . . . . <EOS>
#
# > architects love to hate it .
# = kien truc su luon ghet no .
# < nhung e la no . . . . <EOS>
#
# > i said i worked eight or nine years on it .
# = toi a noi toi lam viec tam hoac chin nam voi no .
# < toi toi toi toi toi toi toi toi . . . <EOS>
#
# > and again closely related to inequality .
# = va mot lan nua gan lien voi su bat binh ang .
# < va hay thu la la la . . <EOS>
#
# > so how do we recover from that ladies and gentlemen ?
# = vay chung vuot qua kho khan nay nhu the nao thua quy ong va quy ba ?
# < vay chung chung ta chung co the the nhung va <EOS>
#
# > the first one that david saw was human evil .
# =  ieu au tien ma david nhan thay o la toi ac cua loai nguoi
# <  au la la la la la la <EOS>
#
# > we coat the outside with these muscle cells .
# = phu ben ngoai voi cac te bao co
# < chung ta la la nhung nhung nam . . <EOS>
#
# > eric whitacre a virtual choir voices strong
# = eric whitacre dan hop xuong ao voi giong hat
# < vi vi la la la la la <EOS>
#
# > and so why don apos t we go and click the video .
# = va tai sao chung ta khong chon video
# < va chung chung ta la chung chung va chung . va <EOS>
#
# > and not only that when i was eight i became a child soldier .
# = khong chi vay khi len toi i linh .
# < va co la la toi toi toi la toi la toi toi <EOS>
#
# > thank you .
# = xin cam on
# < cam on . . <EOS>
#
# > two groups of mujahideen started fighting .
# = hai nhom mujahideen bat au ban nhau .
# < nhung co la la la la la . <EOS>
#
# > many of those patients are very severely burned .
# = nhieu benh nhan trong so o bi bong rat nang
# < rat nhieu la la la la la la la <EOS>
#
# > so today we apos re going to show you one example of how you can use this .
# = cho nen hom nay toi se chi cho cac ban mot vi du ve cach su dung no .
# < vi vi chung ta biet chung ta ban ban ban ban ban ban e . . <EOS>
#
# > for example george bush target practice shooting at bin laden and michael moore .
# = lay vi du canh george bush ang tap ngam lay muc tieu la bin laden va michael moore .
# < vi vi vi la la la la su va va va va va . <EOS>
#
# > just two things .
# = chi hai thu thoi
# <  co nay . . <EOS>
#
# > i apos ll meet you there . quot
# = toi se gap ban o o . quot
# < toi se quot quot quot . quot .  <EOS>
#
# > be a hero . this is your chance .
# = lam nguoi hung . ay la co hoi cua ban .
# <  ay la . la . la . . . . <EOS>
#
# > i was o .k . that apos s fine .
# = toi noi uoc roi tot thoi .
# < toi a la . . . . . <EOS>
#
# > we don apos t talk about the sacrifice .
# = chung ta khong noi ve nhung hy sinh .
# < chung ta khong chung la la la <EOS>
#
# > and it doesn apos t mean it apos s going to work forever .
# = va no se khong hoat ong mai mai .
# < va no khong no la no la no . <EOS>
#
# > and how they have been achieved . . .
# = va nguoi ta a at uoc no nhu the nao
# < va chung chung chung co chung . . . . . <EOS>
#
# > they were wild posted around new york city .
# = dan hang loat vong quanh thanh pho new york .
# < ho co co nhung nhung nhung hon . <EOS>
#
# > i was in oman and i was in saudi arabia .
# = toi a en oman saudi arabia .
# < toi a la va va va va va <EOS>
#
# > we could pay professional language translators to translate the whole web .
# = chung toi co the tra cho chuyen gia dich thuat e dich toan bo web .
# < chung ta co the co nhung e nhung e nhung e <EOS>
#
# > how can you invest in africa when there apos s corruption ? quot
# = lam the nao ban co the au tu vao chau phi khi co tham nhung ?
# < co co co co the the nhung co nhung nhung ? <EOS>
#
# > the old stars they come to life .
# = nhung ngoi sao cua thoi ai truoc . ho en voi cuoc song .
# <  au la chung chung la . . <EOS>
#
# > i have never been more terrified until now .
# = toi chua bao gio cam thay kinh hai nhu luc o cho en bay gio .
# < toi co co co co nhung nguoi nguoi . <EOS>
#
# > and there was a little an interesting theory about abstraction .
# = va co mot thuyet truu tuong thu vi nhu the nay .
# < va co mot mot mot mot mot mot mot <EOS>
#
# > as a result we had to streak and restreak several times .
# = do vay chung toi phai tach i tach lai nhieu lan .
# < mot la chung ta chung ta chung chung ta va va <EOS>
#
# > and it sits in the membrane of the cell and it apos s got a pore in it .
# = va chung nam tren mot mang cac te bao va co mot khe trong chung
# < va no la la nam nam va va nam va <EOS>
#
# > and for him it apos s only his second .
# = va voi cau no chi la lan thu .
# < va co la la la la la <EOS>
#
# > so can you read it ?
# = ban co the oc no khong ?
# < vay co co co the co the ? <EOS>
#
# > speed x .
# = toc o x .
# <  e la . <EOS>
#
# > and these genes are activated mainly by estrogen .
# = va nhung gen nay uoc kich hoat chu yeu boi estrogen .
# < va o la la la la la nhung . <EOS>
#
# > this would imply a massive leap in migration .
# =  ay ngu y ve mot khoang cach kha lon trong viec di an .
# <  ay la mot mot mot mot . . <EOS>
#
# > the scene of arrest the scene of misidentification the alibi location .
# = hien truong bat giu noi nhan dien nham ia iem cua chung co ngoai pham .
# < nhung nhung la la la la la cua cua la cua <EOS>
#
# > and the reason is after world war ii we changed our farming practices .
# = va ly do la sau the chien thu hai chung ta a thay oi tap quan canh tac .
# < va la la la la la nhung chung ta chung ta ta chung <EOS>
#
# > i apos m feeling it .
# = toi ang cam nhan uoc ieu o .
# < toi la . . . <EOS>
#
# > and humility because we are all human . we all make mistakes .
# = va khiem ton va chung ta eu la con nguoi . chung ta eu sai lam .
# < va vi chung chung chung ta chung ta chung ta chung ta . . <EOS>
#
# > okay ? one two three go !
# = ok ? mot hai ba i !
# <  co co co co <EOS>
#
# > back to you henry .
# = tro lai phan anh henry .
# < hay e . ban . . . <EOS>
#
# > i apos ve assembled for your pleasure here seven deadly sins of speaking .
# = o ay toi a tap hop bay loi chet nguoi trong giao tiep .
# < toi la la mot la cua cua cua cua . . . <EOS>
#
# > but nine of the in those first hours .
# = nhung trang trong nhung gio au
# < nhung nhung nam la la la la nam . <EOS>
#
# >  . . . don apos t you feel ?
# =  . . . quy vi co thay vay khong ?
# <  . . . . . <EOS>
#
# > and the approach has basically been to just sort of fund things as they come along .
# = va phuong phap nay co ban ai loai la ve ngan sach
# < va la la la la la la la e nhung e nhung nhung e nhung <EOS>
#
# > it is absolutely possible .
# = ho hoan toan co the .
# < no la la la . <EOS>
#
# > there are a lot of problems with this question .
# = co rat nhieu van e voi cau hoi nay .
# < co co mot rat rat co rat e <EOS>
#
# > and i went to see the dozo .
# = va toi a i gap nhung nguoi dozo .
# < va toi a co mot co . <EOS>
#
# > you know because they can apos t hear the snoring anymore .
# = cac ban biet ay la vi ho khong the nghe tieng ngay ngu nua
# < ban biet biet biet biet biet biet biet biet biet co the <EOS>
#
# > i come from lebanon and i believe that running can change the world .
# = toi en tu nuoc lebanon va toi tin rang chay co the thay oi the gioi
# < toi co toi toi va va va va va va va va toi <EOS>
#
# > last march we received very sad news .
# = thang ba vua qua chung toi nhan uoc mot tin buon
# < nhung vi chung toi chung toi la la . <EOS>
#
# > so let apos s do that . let apos s think .
# = hay lam no . hay tu duy .
# < hay hay hay no la . . . . <EOS>
#
# > i was so happy .
# = toi rat vui .
# < toi la . . . <EOS>
#
# > what would be a good end of life ?
# = the nao la mot ket thuc co hau cho cuoc oi nhi ?
# < anh co la la la la la cua <EOS>
#
# > and now when the kid comes it apos s an experience .
# = khi bon tre em o se la mot trai nghiem
# < va khi co toi la mot la la mot <EOS>
#
# > we go from this view out to the stars .
# = chung toi bat au tu goc nay va i ra ngoai nhung ngoi sao
# < chung ta toi co nhung e la e . <EOS>
#
# > you apos d think it would be otherwise but it isn apos t .
# = ban nghi la no se khac nhung khong .
# < ban co biet khong no thay no no no <EOS>
#
# > this is from hama .
# =  ay la o hama .
# <  ay la la la . . <EOS>
#
# > this is from a short film quot adventures with skinny . quot
# =  ay la trich tu mot bo phim ngan quot cuoc phieu luu cua chang gay quot .
# <  ay la mot quot quot quot quot quot quot quot quot . <EOS>
#
# > jane mcgonigal the game that can give you extra years of life
# = jane mcgonigal tro choi co the trao cho ban them nam e song
# < nhung nhung nhung co la la co co co nhung nhung <EOS>
#
# > but that alone doesn apos t give us the road map .
# = nhung chi rieng cac cong cu nay thi van chua u e giai quyet .
# < nhung nhung no khong khong la khong la khong nhung <EOS>
#
# > you could be a random fluctuation out of the nothingness .
# = ban co the la mot dao ong ngau nhien xuat hien tu hu khong .
# < ban co co co mot mot nhung ve nhung ve <EOS>
#
# > no but they had a major impact .
# = khong nhung no co anh huong lon .
# < nhung chung co khong co co co . <EOS>
#
# > let apos s begin by winding the timeline back . billion years to the beginning of time .
# = hay bat au bang viec quay nguoc thoi gian ti nam e bat au mot thoi ai .
# < hay au la la la la nam e la nam . . . <EOS>
#
# > you see it there ? there ? watch it come down .
# = cac ban co thay khong ? kia kia ? xem no xuong .
# < ban co co the ? ? ? ? ? ? ? <EOS>
#
# > chris farina is here today at his own cost .
# = hom nay cau ay tu tra tien e en ay .
# <  thu la la la la la la cua cua <EOS>
#
# > these are mine i was born an argentinean .
# = nhung cai o la cua toi toi sinh ra la mot nguoi argentina .
# <  ay la toi toi la la mot mot <EOS>
#
# > but let me tell you a bit about it today .
# = nhung ngay hom nay hay e cho toi ke cho cac ban mot it ve no .
# < nhung hay toi toi mot mot mot e mot <EOS>
#
# > and finally he said quot ruby i see that you apos re talking .
# = cuoi cung ong noi quot ruby chu thay rang chau ang noi ma .
# < va anh ay biet noi biet noi quot la la la quot <EOS>
#
# > thank you so much .
# = xin cam on .
# < cam on cac nhieu nhieu <EOS>
#
# > because meetings aren apos t work .
# = vi hop hanh chang giai quyet uoc gi ca .
# < khong vi khong khong khong khong . . <EOS>
#
# > so it apos s fair to ask how is it possible for them to change this ?
# = do vay noi cong bang ra lam sao ho co the thay oi uoc ieu nay ?
# < vay no la phai la e la e e e e e <EOS>
#
# > robert full he talked about the tail being a whip for communication .
# = anh ta a noi cai uoi co vai tro lam roi e giao tiep .
# <  ieu la la la la la la la la la . . <EOS>
#
# > and i think you matter .
# = va toi cho rang ban quan trong .
# < va toi nghi thay . . . <EOS>
#
# > a few years ago i did a meditation retreat in thailand .
# = vai nam truoc toi i thai lan e thien an dat .
# < mot nam nam toi toi toi toi mot mot mot <EOS>
#
# > worms have a little bit of a problem grabbing the headlines .
# = giun co nhieu van e hon la tren cac tieu e .
# < co co mot mot mot mot mot mot mot <EOS>
#
# > so actually how do we harvest this bone marrow ?
# = vay the chung toi a lay tuy nhu the nao ?
# < vay chung chung chung chung ta chung ta the <EOS>
#
# > you can open it up completely . it apos s waterproof .
# = ban co the mo no ra . ben trong la chat lieu chong tham nuoc lien manh
# < ban co co no co no no no no . . . <EOS>
#
# > and the color now is the majority religion .
# = va mau sac la ton giao chu yeu .
# < va la la la la la . <EOS>
#
# > but it is a place where sex workers and their clients come .
# = ma la mot noi nhung co gai mai dam va khach cua ho en .
# < nhung no la la la la va co va co co . <EOS>
#
# > this is the boat we were on by the way .
# =  ay la thuyen cua chung toi .
# <  ay la la la la la chung ta <EOS>
#
# > about interventions have been proposed that allegedly make people happy .
# = khoang phuong phap uoc cho rang co the lam con nguoi hanh phuc a uoc ua ra .
# < mot nguoi nguoi nguoi co la la co co co nhung <EOS>
#
# > will never gather up all the plastic and put the ocean back together again .
# = cung khong thu thap lai uoc het nhua va ua ai duong ve trang thai ban au .
# < ban co co the nhung vao va va va va va va . <EOS>
#
# > previous to this time i was very selfish and self righteous .
# = truoc o toi von la nguoi rat ich ki va luon cho minh la ung .
# <  au la toi toi la toi va va va va . <EOS>
#
# > and then look at business .
# = va roi hay nhin vao thuong truong .
# < va no la la . . <EOS>
#
# > but then you lose control of it .
# = nhung roi ban mat quyen kiem soat no .
# < nhung ban ban ban ban ban ban . . <EOS>
#
# > mothers are like that .
# = ba me nao cung nhu nhau .
# <  ieu la la la <EOS>
#
# > these have been private meetings so far .
# =  a co nhieu cuoc hop bi mat uoc to chuc .
# < co co co co co co co . <EOS>
#
# > i go quot he apos s got to be my driver . quot
# = toi nghi quot chac ga nay la tai xe cua minh . quot
# < toi noi quot quot quot quot quot quot quot quot quot quot <EOS>
#
# > but perhaps the most important invention the most important invention is machine learning .
# = nhung co le sang che quan trong nhat sang che quan trong nhat chinh la may hoc tap .
# < nhung nhung nhung la la la la nhung nhung nhung nhung nhung nhung <EOS>
#
# > but i can see in your faces that you apos re still a little bit skeptical .
# = nhung toi van thay chut it hoai nghi tren ve mat quy vi .
# < nhung ban co co co the co nhung co co co co la ban . <EOS>
#
# > that was the media landscape as we had it in the twentieth century .
# =  o chinh la toan canh ve truyen thong ma chung ta co trong the ky .
# <  ay la la chung chung chung chung chung ta chung chung <EOS>
#
# > he was living with a girl outside london .
# = anh ta ang song voi mot co gai o ngoai o london .
# < anh ay la mot mot mot . . . <EOS>
#
# > geert chatrou thank you . thank you .
# = geert chatrou cam on . cam on .
# < cam on . . ban . ban . . . <EOS>
#
# > michael shermer the pattern behind self deception
# = michael shermer quy luat ang sau viec tu lua doi ban than
# < david ai cua cua cua cua cua <EOS>
#
# > if you can apos t write about yourself anymore then who do you write about ?
# = neu ban khong the viet ve minh nua thi ban se viet ve ai ay ?
# < neu ban co ban co biet co co khong nhung co nhung co nhung <EOS>
#
# > well guess what ?
# = cac ban biet khong ?
# <  gi gi ? ? ? <EOS>
#
# > i didn apos t want anyone to know that i was a girl and they didn apos t .
# = toi khong muon ai biet toi la con gai va khong ai biet thiet .
# < toi khong khong khong khong khong la khong la khong toi la . <EOS>
#
# > now you turn the crank once twice twice marvels come out .
# = roi ban xoay hinh nay mot lan hai lan . hai lan ieu ky dieu se xay ra .
# < ban ban co co thay co mot mot nguoi nhung hon <EOS>
#
# > the media love it they really adore it .
# = cac phuong tien truyen thong yeu thich va quy men no .
# <  au la chung chung chung chung no . <EOS>
#
# > why is that important ?
# = tai sao ieu o lai quan trong ?
# < tai sao la la ? ? ? <EOS>
#
# > so that when it gets dark i apos ve got plenty of power .
# = vi vay khi troi tot toi se co ay nang luong .
# <  o no la la no toi toi toi la va . <EOS>
#
# > kids can be full of inspiring aspirations and hopeful thinking .
# = tre em co nhieu nhung nguyen vong tran ay cam hung va nhung suy nghi ay hy vong
# < co co co co co nhieu nhieu va va va va . <EOS>
#
# > let apos s just come down a bit and fly around .
# = hay i xuong mot chut va bay vong .
# < hay e la la va mot . <EOS>
#
# > what happens is two thirds of the kids give in to temptation .
# = tren thuc te hai phan ba lu tre nhuong bo truoc su cam do .
# < nhung ay la la la nhung nhung la nhung nhung la nhung <EOS>
#
# > and we apos re going to play just the very tail end of this symphony now .
# = va chung toi se choi oan cuoi cua ban giao huong ngay bay gio .
# < va chung toi se e ve e e e e . . . <EOS>
#
# > somebody else is in there ahead of them .
# = ai o a chay bat bong truoc roi .
# <  nguoi la la la la la . . <EOS>
#
# > the world bank president was a third grader one time .
# = chu tich ngan hang the gioi a la tung la hoc sinh lop
# <  nguoi la la la la la la la nguoi <EOS>
#
# > and that apos s my friend . i mean i charge it every night .
# =  o chinh la ban toi . y toi la toi sac no moi toi .
# < va o la la . toi toi toi toi toi toi . . . . <EOS>
#
# > but the wealth gaps are growing wider .
# = nhung khoang cach giau ngheo ang ngay cang rong ra .
# < nhung nhung cung la la la la . <EOS>
#
# > so speech is the primary mode of communication delivered between all of us .
# = loi noi la phuong tien giao tiep chu yeu giua tat ca chung ta .
# < vi vi la la la la la cua nhung ta chung ta ta <EOS>
#
# > we have secularized badly i would argue .
# = chung ta a tran tuc hoa toi toi cho la vay .
# < chung ta co co nguoi nguoi nguoi la . <EOS>
#
# > it apos s that afraid of the water .
# =  o la tinh so nuoc .
# < no o la la la cua <EOS>
#
# > there apos s like two million people on copacabana beach .
# = co khoang trieu nguoi tren bo bien copacabana .
# < co co co nguoi nguoi nhung hon <EOS>
#
# > so this is only once .
# =  o la lan duy nhat .
# <  ay la la la la . <EOS>
#
# > i looked a lot like an orangutan our close cousins or the incredible hulk .
# = toi trong giong con uoi uoi ho hang gan voi chung ta hoac ga khong lo sieu quay
# < toi la mot mot mot mot mot mot la mot nhung mot <EOS>
#
# > and i said quot how long have you been a fireman ? quot
# = toi lai hoi quot anh lam uoc bao lau roi ? quot
# < va co quot quot quot quot quot quot quot quot quot quot ? quot <EOS>
#
# > sound places us in space and in time .
# = am thanh at chung ta vao khong gian va thoi gian .
# < co nam nam nam va va va va va <EOS>
#
# > i apos m not doing anything bad or anything illegal .
# = toi khong lam gi xau hay pham phap
# < toi khong khong khong la . . . . . <EOS>
#
# > she managed to study english and learn that as a foreign language .
# = ba co gang hoc tieng anh va hoc no nhu la mot ngoai ngu .
# < co co mot co mot va va va va mot va . <EOS>
#
# > it may even feel scary .
# = tham chi no con ang so .
# < no co la la . . <EOS>
#
# > there apos s a world bank arms dealers and a united nations .
# = co mot ngan hang the gioi thuong nhan chi nhanh va mot lien hop quoc
# < co co mot mot co mot co va co . <EOS>
#
# > we live in the dusk of an era .
# = chung ta song trong buoi hoang hon cua mot ky nguyen .
# < chung ta la la mot nam nam . <EOS>
#
# > this is a detail of a chair that i apos ve designed in magnesium .
# =  ay la chi tiet cua chiec ghe toi a thiet ke bang ma gie .
# <  ay la mot mot la mot la toi toi la . . <EOS>
#
# > now this is quite time consuming and isn apos t the most comfortable process .
# = viec nay kha ton thoi gian va khong phai qua trinh thoai mai nhat .
# <  ay la la la va va va va va va va . <EOS>
#
# > miko i don apos t think so .
# = miko minh khong nghi vay .
# < toi toi khong khong khong . . <EOS>
#
# > and this brings up mentors .
# =  ieu nay can en cac co van .
# < va ay nay la la . . <EOS>
#
# > and the pitches the notes as you know are just vibrations .
# = va o cao thap am thanh cac not nhac nhu cac ban biet chi la nhung am rung .
# < va cau la la la la ban ban ban ban biet <EOS>
#
# > and we talk about the world flattens as being this panel and i am very optimistic .
# = va chung ta a noi ve the gioi ang dan phang toi rat lac quan .
# < va chung toi co co nhung nhung co nhung co nhung co la nhung nhung <EOS>
#
# > you apos re arab muslim living in iraq .
# = ban la nguoi a rap ao hoi song o iraq .
# < ban co la nhieu cac . . . <EOS>
#
# > so finally texture is something .
# = cong trinh cuoi cung ket cau la cai gi o .
# < vi vay la la la la . <EOS>
#
# > carbon dioxide level has gone up and up and up .
# = nong o co tang khong ngung .
# <  o la la la va va va va va va <EOS>
#
# > so on the left hand side input equals output which goes down .
# = o phia ben tay trai au vao tuong uong ket qua au ra la i xuong .
# < vi the co co hon la hon la hon hon . . <EOS>
#
# > dn design nature art . these are the three things that condition my world .
# = ttn thiet ke tu nhien nghe thuat yeu to rang buoc the gioi cua toi .
# < nhung nguoi nhung nay nay nay la la la la la la . <EOS>
#
# > so steve how about let apos s zap the brain with electricity ?
# = steve a vay viec dung ien thi sao ?
# < vay hay hay hay e e e e ? ? <EOS>
#
# > everybody has an opinion .
# = moi nguoi co mot quan iem rieng
# < co mot la mot . . <EOS>
#
# > i believe our cars can talk about us behind our backs .
# = toi tin rang xe co se ban tan ve chu chung sau lung chung ta .
# < toi co nhung co nhung nhung nhung nhung ta chung ta chung ta <EOS>
#
# > already i apos ll give you an example .
# = chung a xay ra toi se chi cho ban mot vi du .
# < toi toi la ban ban mot mot . . <EOS>
#
# > but i really did struggle for financial support .
# = nhung toi cung thuc su au tranh cho viec uoc ho tro tai chinh .
# < nhung toi toi toi mot mot . . . . <EOS>
#
# > but it apos s also used to assign a temperature range .
# = tuy nhien no cung uoc dung e ky hieu mot pham vi nhiet o .
# < nhung no la la la la la la mot <EOS>
#
# >  year old men and women are running as fast as they were at age .
# = nhung nguoi an ong va phu nu tuoi chay nhu khi ho tuoi .
# <  nguoi la va va va va va va va va . . <EOS>
#
# > how can i understand those invisible forces ? quot
# = lam sao em co the hieu uoc nhung ong luc vo hinh o ? quot
# < co toi co the the the nhung the the <EOS>
#
# > if you ask anyone quot what is morality based on ? quot
# = neu cac ban hoi bat ky ai quot ao uc dua tren ieu gi ? quot
# < neu co co co co quot co quot co quot ?  <EOS>
#
# > and it anchors itself in the sand by blowing up a balloon on the end of its stock .
# = va no neo minh trong cat bang cach thoi cang mot bong bong o cuoi than .
# < va no la la trong la trong la trong la trong la trong <EOS>
#
# > well i think that should be the minimum .
# = vang toi nghi o la toi thieu .
# < toi toi nghi nghi la la la . <EOS>
#
# > it has been used to help communities prepare for disasters .
# = no a uoc dung e ho tro cac cong ong chuan bi cho cac thien tai .
# < no no la no e . e . . . . <EOS>
#
# > scientists can say no it apos s false .
# = ho co the noi khong neu la sai .
# < co co co co the co khong . <EOS>
#
# > we can take it completely for granted .
# = chung ta co the cho rang ay la ieu hoan toan hien nhien .
# < chung ta co the the the nhung co . <EOS>
#
# > so mr . gore thank you .
# = thua ong al gore rat cam on ong .
# < cam on . . . . . . <EOS>
#
# > so if christian played a note like play an f .
# = va neu christian choi mot not nhac nhu not pha .
# < vi co co co co mot mot mot mot mot mot <EOS>
#
# > so there is no life possible at that type of mutation rate .
# = vay thi khong co su song ton tai tai muc o bien oi o .
# < vi the co co co co la la co co co <EOS>
#
# > human relationships are rich and they apos re messy and they apos re demanding .
# = quan he cua con nguoi phong phu va hon on va yeu cau cao .
# <  nguoi la la va va va va va va . <EOS>
#
# > clearly a complex problem but is it complicated ?
# = ro rang ay la mot van e phuc tap nhung lieu no co rac roi khong ?
# < co co la la nhung co la <EOS>
#
# > and that apos s a very important trend to think about .
# = va o la mot xu huong rat quan trong ang uoc xem xet
# < va o la mot mot mot la mot e <EOS>
#
# > and he says quot they apos re their personnel records . quot
# =  quot o la ghi chep nhan su cua ho ma quot
# < va co quot quot quot quot quot quot quot quot .  <EOS>
#
# > none of it apos s a distractor so we lose that .
# = khong co gi la thua o ay vi vay chung ta thieu ieu o .
# <  chung chung la la la la chung ta chung <EOS>
#
# > you can live in a small poor country like me .
# = ban co the song trong mot at nuoc nho ngheo kho nhu toi .
# < ban co co co mot mot mot mot co nhung . <EOS>
#
# > the third child doesn apos t really come back .
# =  ua tre thu ba khong that su quay lai
# < khong la khong la khong la . <EOS>
#
# > and this is a video that has actually won an award as the best documentary of the year .
# = va no la mot bo phim a uoc giai phim tu lieu hay nhat cua nam .
# < va ay la mot la mot la mot la mot la mot la mot <EOS>
#
# > simple as that .
# =  on gian nhu vay .
# < nhung co co . . <EOS>
#
# > sending mail to japanese design magazines and things like that .
# = nhu gui thu cho tap chi thiet ke nhat ban hay nhung thu tuong tu .
# <  e la thu toi va va va va va . <EOS>
#
# > and now here comes the other pirate .
# = gio thi mot ten cuop bien khac en .
# < va ay ay la mot la . . <EOS>
#
# > here apos s we apos re going to just show a short clip from this baghdad airstrike video .
# = chung ta vua xem mot oan phim ngan tu video ve cuoc khong kich vao baghdad .
# <  ay la la la e mot e e e e . . <EOS>
#
# > so there apos s always a strong ecological component in the project .
# = do o luon co mot thanh phan sinh thai manh me trong e an .
# < vi vay la la mot la mot la . . <EOS>
#
# > ghana got very ahead fast .
# = ghana tien bo rat nhanh .
# < co rat nhieu nhieu . . . <EOS>
#
# >
# =
# <  <EOS>
#
# > they were two lifetimes of the same hero .
# = ho la quang oi cua cung mot nguoi anh hung .
# < ho co co nhung nhung nhieu nhung . <EOS>
#
# > and whenever i apos d go to the local butcher to purchase some halal meat something felt off .
# = bat cu khi nao mua thit halal trong vung toi thay co gi o khong on .
# < va toi toi co ho la nguoi nguoi nguoi nguoi nguoi nguoi nguoi nguoi nguoi <EOS>
#
# > we need that in the world .
# = chung ta can no tren the gioi nay .
# < chung ta co the nhung nhung <EOS>
#
# > you need to reward those who cooperate and blame those who don apos t cooperate .
# = ban can thuong cho nhung ai hop tac va phe binh nhung ai khong lam vay
# < khong phai phai nhung nhung va va va va va va va va <EOS>
#
# > and they brought this kind of a jeweled parasol and they put it on the ground .
# = ho mang theo loai du trang suc nay va at chung duoi at .
# < va ho la la mot nhung va va mot nam va va . <EOS>
#
# > and the answer is all of them .
# = va cau tra loi la tat ca chung .
# < va la la la la la . . <EOS>
#
# > why would they appear only to cranks and weirdoes ?
# = tai sao chung chi xuat hien truoc mat lu do hoi lap di ?
# < tai sao chung chung co nhung nhung nhung ? <EOS>
#
# > mau is a palu a navigator priest .
# = mau la mot palu mot truong tau
# <  mot mot mot mot mot mot mot <EOS>
#
# > it apos s come through trial and error .
# = no toi thong qua phep thu va sai sot .
# < no la la la va va . <EOS>
#
# > they said we won apos t think about it until we know it apos s right .
# = ho noi rang ho se khong suy nghi gi ca cho en khi ho chac chan rang ung
# < chung ta chung chung chung chung chung chung chung chung la la <EOS>
#
# > so we went out and found these dodgeball teams and infiltrated them .
# = vi vay chung toi tim gap nhung oi bong ne nay va xam nhap vao ho
# < vi chung toi toi chung va va va va va va va va <EOS>
#
# > and i say because . . . because .
# = va toi noi boi vi . . . boi vi .
# < va toi toi . . . . . . . . . <EOS>
#
# > i apos ll give you one more example for this .
# = toi se cho them vi du .
# < toi se cho mot mot e . e . . . <EOS>
#
# > so why don apos t you do that now ?
# = gio ban hay lam vay
# < vay sao sao sao gi gi gi ? ? ? <EOS>
#
# > they spend on the d part of r amp amp d .
# = ho chi tieu cho phan phat trien trong chuong trinh nghien cuu va phat trien .
# < ho co co co co hon hon nhung hon . <EOS>
#
# > so you apos re in a big corporation .
# = vay ban ang o trong mot tap oan lon
# < vi ban ban co mot mot mot <EOS>
#
# > by the time they apos re five they won apos t be able to do that anymore .
# =  en luc len chung se khong con kha nang o nua
# < nhung nguoi la chung chung la la chung chung la khong <EOS>
#
# > i apos m just simply saying that a world without love is a deadly place .
# = toi chi noi on gian rang mot the gioi khong co tinh yeu la mot noi chet choc .
# < toi la la mot mot mot mot mot mot mot la mot <EOS>
#
# > and god says quot moses what apos s in your hand ? quot
# = va chua noi rang quot moses cai gi trong tay con vay ? quot
# < va co quot co quot quot quot quot quot quot ? ? quot ?  <EOS>
#
# > we mashed the clay with our feet when it came from the hillside .
# = chung toi nghien at set bang chan khi no uoc mang ve tu chan oi .
# < chung ta la la la nam nam chung chung chung nam . <EOS>
#
# > so we have portal because you shoot walls in order to create new spaces .
# = chung ta co tro portal vi ban ban vao tuong e tao nhung khong gian moi .
# < vi chung chung co co co co co co co co nhung nhung trong . <EOS>
#
# > age not at all as pathology age as potential .
# = tuoi gia khong ong nghia voi benh tat ma la tiem nang .
# < khong co co the nhung co nhung nhung . . <EOS>
#
# > boy it apos s lighting up .
# = cau be no ang sang len .
# < no o la la . . <EOS>
#
# > the social brain is controlling when the babies are taking their statistics .
# = bo nao xa hoi ieu khien khi nhung u tre thu nhap so lieu .
# < khong la la la la la la la la la la la <EOS>
#
# > they want to spend less and save more .
# = ho muon tieu it va tiet kiem nhieu .
# < ho muon nhieu va va va va va . <EOS>
#
# > it apos s got some math that i can do .
# = no co nhung thuat toan ma toi co the lam .
# < no o la mot co co the co the . <EOS>
#
# > genetics has opened the door to the study of human variability .
# = cong nghe gien a mo canh cua cho viec nghien cuu su a dang cua con nguoi .
# < co co la la la la e la e la . <EOS>
#
# > there i go .
# = bat au thoi .
# < toi toi toi . . <EOS>
#
# > he said quot but i wanted to be a fireman . quot
# = anh ta noi quot nhung toi thuc su muon lam mot linh cuu hoa . quot
# < anh quot quot toi toi quot quot quot quot quot quot .  <EOS>
#
# > and you apos d still come out ahead .
# = va cac ban se van co loi .
# < va ban ban ban ban la . . <EOS>
#
# > women are dying of heart disease two three four times more than men .
# = phu nu ang chet vi benh tim cao gap lan so voi nam gioi
# < co co co nguoi nhung hon hon hon hon hon hon hon . <EOS>
#
# > i had frostbite in my left big toe .
# = ngon chan cai ben trai cua toi bi phong lanh .
# < toi a la nhung la nhung nhung . . <EOS>
#
# > and we apos re finding more and more and more gender differences in the brain .
# = va chung ta ang tim thay them nhieu nua nhung khac biet gioi tinh trong nao bo .
# < va chung co co the va va va va va va <EOS>
#
# > no i don apos t think so .
# = toi khong nghi the .
# < toi khong khong khong khong . . <EOS>
#
# > this is what the green list says .
# =  o la ieu ma danh sach xanh noi .
# <  ay la la la la la . <EOS>
#
# > you get something a little bit more complicated .
# = ta lai co mot thu khac phuc tap hon mot chut
# < ban co co mot mot hon hon hon . <EOS>
#
# > she was one of the doctors who treated victims of the chernobyl power plant meltdown .
# = va la bac si chua tri cho nan nhan trong su co hat nhan chernobyl .
# < co co mot mot la mot cua la la cua cua . . . <EOS>
#
# > ladies and gentlemen i apos d like to end before time .
# = thua qui vi va cac ban toi xin dung som hon du inh .
# < va khi toi toi la la la . . . <EOS>
#
# > and labor statistics women take up most managerial jobs .
# = va cac so lieu ve lao ong phu nu nam hau het cac cong viec quan ly .
# < va va co la la la la cua . <EOS>
#
# > here apos s hellas basin a very very different place geologically .
# =  ay la khu vuc hellas mot noi rat khac biet ve mat ia chat .
# <  ay la mot mot rat rat rat rat rat <EOS>
#
# > the following day president yanukovych fled ukraine .
# = ngay hom sau tong thong yanukovych tron khoi ukraine .
# <  o la la la la . <EOS>
#
# > now where do you find such goldilocks conditions ?
# = bay gio chung ta se tim nhung ieu kien goldilocks o au ?
# < ban co co ban co co co co <EOS>
#
# > a third of all the people commute by bike .
# = mot phan ba cu dan i lai bang xe ap .
# < mot nguoi nguoi nguoi nguoi nhung nguoi nhung nguoi . <EOS>
#
# > these kinds of things .
# = nhung chuyen ai loai nhu vay
# < nhung nhung nay nay la . <EOS>
#
# > marvin minsky health and the human mind
# = marvin minsky noi ve suc khoe va tri tue con nguoi
# < mot ai va va va va <EOS>
#
# > well it apos s times more resistant to electric current than that salt dough .
# = no co ien tro gap lan so voi bot nhao muoi .
# < no no la la hon hon hon hon hon hon hon <EOS>
#
# > but to really kind of personify the movement they wanted to name it .
# = nhung e nhan cach hoa hanh ong cua minh ho a at ten cho no
# < nhung nhung cung nhung la la nhung chung chung chung chung . . <EOS>
#
# > per capita food production is up by a third .
# = luong thuc tinh theo au nguoi tang len
# <  la la la la la mot la mot <EOS>
#
# > everyone can be wrong .
# = ai cung co the sai .
# < co co co the the the . <EOS>
#
# > they have urban streetscapes but suburban parking ratios .
# = ho co ban ve cac con pho o thi voi he so o xe cua ngoai o .
# < ho co co co co nhung nhung co . <EOS>
#
# > learning this i knew there had to be a better way .
# = biet uoc ieu nay toi muon rang tim ra phai co mot cach tot hon .
# < nhung nay toi co toi co mot mot mot mot <EOS>
#
# > well what do we do about them ?
# = vay thi chung ta lam gi oi voi chung ?
# < chung ta chung ta gi gi gi gi ? <EOS>
#
# > an american sprinter jumps out to the front .
# = va van ong vien chay nuoc rut nguoi my nhay ra phia truoc .
# < mot nguoi la la la la la la . <EOS>
#
# > that means we apos d go from to .
# = nghia la ta se tu len .
# <  o chung chung ta chung chung . . <EOS>
#
# > we basically gave children a very simple challenge .
# = ve co ban chung toi cho cac hoc sinh mot thu thach rat on gian .
# < chung ta co mot mot mot mot mot <EOS>
#
# > and tiger woods for a long time the perfect brand ambassador .
# = roi tiger woods suot ca mot thoi ky la ai su hoan hao .
# < va khi la mot mot la mot la mot . . <EOS>
#
# > and really slowly slowly slowly it happened .
# = va that cham rai cham rai cham rai ieu o xay ra .
# < va no cung no no la . . <EOS>
#
# > this is india coming up with the first data from india .
# =  ay la an o ang vuon len voi du lieu au tien tu an o .
# <  ay la la la la tu tu tu tu tu . . <EOS>
#
# > what happened ?
# =  ieu gi a xay ra ?
# < no gi gi ? ? ? <EOS>
#
# > but the problem is that people all didn apos t want all the golf balls .
# = van e la moi nguoi khong muon tat ca cho bong o .
# < nhung nhung co la la co la co khong khong khong nhung nhung nhung <EOS>
#
# > are there any people here under the age of ?
# = vay nhung ai ngoi ay chua en tuoi ?
# < co co co co co co co <EOS>
#
# > i think december th was probably supposed to be th .
# = toi nghi ngay thang thuc ra la ngay .
# < toi nghi la la la la e toi toi <EOS>
#
# > richard seymour how beauty feels
# = richard seymour net ep uoc cam nhan nhu the nao
# < david nhung co nhung co the <EOS>
#
# > i think when i see it i start to think who are those people ?
# = khi xem tranh toi tu hoi nhung nhan vat trong ay la ai ?
# < toi toi nghi toi toi toi toi toi toi toi la toi <EOS>
#
# > on sunday the only thing you can look forward to is the work week .
# = vao chu nhat ieu duy nhat ban mong cho la mot tuan lam viec
# <  e la la la la co co e the e e <EOS>
#
# > and given that i have minutes to do this this is going to go kind of quick .
# = va trong phut o toi muoons i nhanh .
# < va toi toi nghi toi co e la e e nay e nay e <EOS>
#
# > i grew up like this and so did my other three sisters .
# = toi lon len nhu vay cung ba nguoi chi em cua minh .
# < toi a toi va va va va va va va toi . <EOS>
#
# > so that apos s a very important function tied in with the nanopatch .
# =  o la mot chuc nang vo cung quan trong cua nanopatch .
# <  o la mot mot mot mot e la mot <EOS>
#
# > but yet we get the sensation of something happening .
# = tuy nhien chung ta co uoc cam giac ve mot ieu gi o ang xay ra .
# < nhung nhung chung chung chung ta chung co nhung . <EOS>
#
# > first of all translating the web .
# =  au tien dich trang web .
# <  au la la la la . <EOS>
#
# > jonathan drori what we think we know
# = jonathan drori voi quot nhung ieu ma chung ta nghi la minh biet quot
# < tai ta chung chung ta chung ta chung chung <EOS>
#
# > and they immediately went quot there it is . quot
# = va chung ngay lap tuc tra loi quot ay a . quot
# < va co co quot quot quot quot quot . .   <EOS>
#
# > but this is just my own personal ideology .
# = nhung ieu nay chi la tu tuong cua ca nhan rieng toi .
# < nhung ieu la la la la la la . . <EOS>
#
# > he actually made dollars more than that but he didn apos t count it .
# = thiet ra anh ta kiem uoc them o nua nhung ma khong tinh vao ay .
# < anh co nhung nhung nhung nhung no nhung no nhung no nhung no <EOS>
#
# > they were making scary faces to play the caricature of themselves .
# = ho a mang nhung ve mat ang so e ua cot voi dau an cua ca nhan ho .
# < ho co co co nhung cac nhung cac e . . . <EOS>
#
# > so eric come on over .
# = vi vay eric lai ay nao .
# < vi vi la la . . . <EOS>
#
# > there are about you see them here .
# = thi co khoan buc .
# < co co co ban ban ban ban . <EOS>
#
# > and a crocodile walks up a riverbank toward its den .
# = mot con ca sau len bo ve hang .
# < va mot mot mot mot mot mot mot . . . <EOS>
#
# > that apos s not the worst part of it .
# =  o cung khong phai la ieu te hai nhat .
# <  o la la la la la su <EOS>
#
# > einstein the parrot a talking squawking parrot
# = chu vet einstein noi va keu quac quac
# < david mot la la cua la <EOS>
#
# > now if you don apos t trust someone you place restrictions on them right ?
# = neu ban khong tin tuong ai o ban se at cho ho su rang buoc ung khong ?
# < ban ban co khong khong khong khong ban ban co ban ? <EOS>
#
# > whew !
# = ui cha !
# <  ! <EOS>
#
# > we have all this at the same time .
# = tat ca vao cung mot thoi iem .
# < chung ta co co co la la . <EOS>
#
# > i would later find out that was houdini apos s personal record .
# = sau o toi kham pha ra rang o la thanh tich ca nhan cua houdini .
# < toi co toi co la la la toi la la <EOS>
#
# > it apos s got nothing in it .
# = khong co gi ben trong .
# < no o la la . . . <EOS>
#
# > and he said quot well what are you praying ? quot
# = ong noi quot vay chau cau nguyen ieu gi ? quot
# < va anh noi quot quot quot quot quot quot ?   <EOS>
#
# > and even non democratic governments are more sensitive to public opinion .
# = va ngay ca cac chinh phu khong dan chu cung nhay cam hon voi cong luan .
# < va cung cung la la la la e hon e hon . <EOS>
#
# > that means all the boys are going to be add .
# = nghia la tat ca cac cau be se la add .
# <  o la la la la la la . . <EOS>
#
# > now why wouldn apos t this undermine an objective morality ?
# = tai sao ieu nay lai khong lam xoi mon mat khach quan ve ao uc chu ?
# < tai sao sao khong khong la la la ? ? ? <EOS>
#
# > joseph schumpeter called this quot the process of creative destruction . quot
# = joseph schumpeter goi no la quot qua trinh cua su huy diet ay sang tao . quot
# < co quot la quot quot quot quot quot quot quot quot quot . <EOS>
#
# > sw very good .
# = sw tot lam .
# <  on . . <EOS>
#
# > so with all this success why isn apos t that good enough you might ask .
# = voi nhung thanh cong o tai sao chung khong u tot ban co the hoi vay .
# < the the nhung co co co ta ta lam lam lam lam the e <EOS>
#
# > but the over eating and over drinking definitely .
# = nhung toi thuc su an qua nhieu uong qua nhieu .
# < nhung nhung nhung va va va va va <EOS>
#
# > that apos s pretty clearly not a good thing .
# = ro rang khong phai la ieu tot ep .
# <  o la la la la la . . <EOS>
#
# > the answer is no there is no liquid water on the surface of mars today .
# = cau tra loi la khong hien tai khong co nuoc dang long tren be mat cua sao hoa .
# < khong la la la la la la la quot la quot la . . <EOS>
#
# > that interpretation is quite possible and feasible .
# = cach suy dien o la co the va thuc te .
# <  o la la va va va va . <EOS>
#
# > and we got to broadmoor .
# = va chung toi en broadmoor .
# < va chung ta chung chung . . <EOS>
#
# > tm thank you .
# = tm cam on
# < cam on . . <EOS>
#
# > i had to learn mathematics and mechanics and all this sort of thing .
# = toi phai hoc toan va co khi va nhung thu giong vay .
# < toi co co nhung va va va va va va va va va . <EOS>
#
# > i mean that apos s at least how it made me happy .
# =  o la it ra no la cach no khien toi hanh phuc .
# < no toi no la la no no no no no no <EOS>
#
# > makers and shapers and put it togetherers .
# = nhung nha che tao va nhung nha tao hinh va ket hop chung lai voi nhau
# < va va va va va va va . <EOS>
#
# > you see people who are really shell shocked .
# = cac ban thay nhung nguoi dan soc thuc su .
# < ban co co nhieu nguoi nguoi nguoi nguoi nguoi . <EOS>
#
# > it was somebody who was trying to ask a question about javascript .
# = co ai o muon hoi mot cau hoi ve javascript .
# < no la la mot mot mot mot mot la mot <EOS>
#
# > we didn apos t know how critical those first three years were .
# = chung toi khong biet trong nam au oi bo nao cua mot ua tre phat trien the nao .
# < chung ta khong chung chung la la la nhung nhung . <EOS>
#
# > government had no budget .
# = chinh phu khong co nguon kinh phi .
# < khong khong khong khong khong . . <EOS>
#
# > and it shouldn apos t be a guide to all decision making .
# = va nguoi ta khong nen dua vao no e ua ra tat ca quyet inh .
# < va no la khong la la co mot e <EOS>
#
# > and the daughter was exhausted from caring for her mother .
# = va co con gai kiet que vi cham soc cho me .
# < va nam la la la la la nam cua . <EOS>
#
# > what would you like for me to talk about ?
# = vay cac anh muon toi noi ve cai gi ?
# < anh co co gi gi gi gi gi gi ? ? <EOS>
#
# > and sort of the big motto of the anti globalization movement . right ?
# = kieu nhu mot ton chi lon cua phong trao phan toan cau hoa .
# < va co la la la la la cua nhung cua nhung . . <EOS>
#
# > and yet the fundamental patterns underlying them are the same .
# = vay ma nhung mo hinh co ban an duoi nhung van e nay lai giong nhau .
# < va nhung la la la la la la la la <EOS>
#
# > i apos m the ted bundy of string theory .
# = toi la ted bundy cua thuyet day .
# < toi la la mot la cua cua <EOS>
#
# > you could do parallel and series circuits for kids using this .
# = ban co the tao cac mach ien song song va noi tiep cho nhung ua tre su dung .
# < ban co the the nhung nhung va va va va . . <EOS>
#
# > they apos re also harmless plankton feeding animals .
# = ngoai ra chung la nhung ong vat an sinh vat phu du hoan toan vo hai .
# < chung la la la nhung . . <EOS>
#
# > and there apos s the temperature up there in .
# = va nhiet o tang len trong nam .
# < va co co la la <EOS>
#
# > how do you change your behavior ?
# = lam sao e thay oi nhung hanh vi ban nang nay ?
# < co co co the the the ? ? <EOS>
#
# > you don apos t plan what apos s going to happen .
# = ban khong the len ke hoach cho nhung gi se dien ra .
# < ban ban biet biet la la . . <EOS>
#
# > you apos ll see that the temperature is not random .
# = ban se thay nhiet o khong he ngau nhien
# < ban ban biet ay la la la la la . <EOS>
#
# > and that apos s my final slide .
# =  a het phan trinh bay cua toi .
# < va o la la la . . <EOS>
#
# > is it teenage years ? is it middle age ?
# = tuoi thieu nien chang ? tuoi trung nien chang ?
# < no co la la la la ? ? <EOS>
#
# > i was in the cloud .
# = toi lai o trong am may .
# < toi la la la . <EOS>
#
# > i broke some bones in my feet .
# = mot so xuong o ban chan cung bi gay
# < toi a nhung nhung trong . . . <EOS>
#
# > one is that you can apos t be tmsed without knowing it .
# = mot la ban khong the bi tms ma khong biet .
# < mot ieu la co co co khong co co the la . <EOS>
#
# > you can program the hundreds of muscles in your arm .
# = ban co the lap trinh cho hang tram co bap trong canh tay .
# < ban co co the the nhung nhung nhung nhung nhung nhung <EOS>
#
# > and they had some in my opinion terrible christmas music .
# = va toi nghi ho co nhung bai nhac giang sinh that te .
# < va ho co nhung nhung nhung nhung nguoi nhung nhung <EOS>
#
# > you should be in the art department . quot
# = ban phai vao khoa my thuat moi ung . quot
# < ban co co the nhung quot quot quot . <EOS>
#
# > that apos s all we could do .
# =  o la tat ca nhung gi chung ta co the lam
# <  o la chung chung ta chung ta <EOS>
#
# > graham hill less stuff more happiness
# = graham hill gon gang hon hanh phuc hon
# < david nhung co nhung co hon <EOS>
#
# > there have been many articles written .
# =  a co nhieu bai viet .
# < co co nhieu nhieu nhieu nhieu . <EOS>
#
# > the poor man he was on homeopathic medicine .
# = chang trai toi nghiep anh ta ang dung thuoc homeopathy .
# <  nam la la la la la . . <EOS>
#
# > we need to help to lift them out of poverty .
# = chung ta can phai giup ho thoat khoi oi ngheo .
# < chung ta can phai e e e e e e . <EOS>
#
# > they were gesticulating they were running around .
# = ho ang khoa chan mua tay ang chay vong quanh
# < ho co ho chung nhung co . . . <EOS>
#
# > it apos s actually basically three square rooms with a couple of skylights and stuff .
# = ve co ban no co phong vuong voi cua so tren mai nha va cac thu khac .
# < no la la la la nhung e la e nhung e . . <EOS>
#
# > cheers mate .
# = han hanh .
# <  e . . <EOS>
#
# > so i had some sand sprayed in the side of my face .
# = the la toi thay cat vang tren mat .
# < vi toi toi co co co nhung trong trong trong o cua <EOS>
#
# > now what stands in the way of this ?
# = vay ieu gi can tro ieu nay ?
# < nhung co nay gi gi gi gi gi ? <EOS>
#
# > you know there apos s two ways you can make a product .
# = nhu ban biet co hai cach ban co the tao ra mot san pham .
# < ban co biet co co co co the co ban the <EOS>
#
# > gordon brown wiring a web for global good
# = gordon brown lien ket mot mang luoi vi loi ich toan cau .
# < mot mot co mot co e e <EOS>
#
# > there was some other weird stuff that i think my mom should know about .
# = thay vao o la mot so thu ki la ma toi nghi me nen biet
# < co co mot nhung nhung toi toi co toi toi la toi toi <EOS>
#
# > which one did you prefer ? the first one .
# = nguoi an ong anh thich cai nao hon ? nguoi an ong cai au tien .
# <  nay ban ban ban ban la la . . <EOS>
#
# > that is very very important .
# =  ieu o la toi quan trong .
# <  ieu la rat la rat <EOS>
#
# > home .
# = gia inh .
# <  . . <EOS>
#
# > largely it apos s the media who are to blame for this sort of thing .
# = noi chung truyen thong ang bi o loi cho chuyen nay .
# < no o la la la la la e la e e nhung e <EOS>
#
# > well here apos s my suggestion .
# = vang sau ay la goi y cua toi .
# <  ay la la . . <EOS>
#
# > what apos s up ted people ? let me hear you make some noise .
# = lam gi i chu nhung nguoi cua ted ? cho toi nghe gi o i nao .
# < co ay la nhung ban ban ban ban ban ban the . <EOS>
#
# > ok . what apos s that all about ? well i do know a couple of things .
# = vang . tat ca nhung ieu o nghia la gi ? vang toi biet uoc mot so ieu .
# <  vi la la la la la toi la toi la toi la . <EOS>
#
# > the most effective bow for me would be like this .
# = cai cung hieu qua nhat oi voi toi la cai nay .
# < hay e nay nay nay nay toi la toi la . <EOS>
#
# > the larger point i apos m trying to make is this .
# = sau ay la van e lon hon ma toi muon neu ra .
# <  nay toi toi la la la e e . . <EOS>
#
# > so how do you actually go around finding online criminals ?
# = vay thi lam the nao bay gio e tim bon toi pham truc tuyen ?
# < vay sao co co the the the nhung nhung nhung ? <EOS>
#
# > blood test results are this great source of information .
# = ket qua kiem tra mau mau la mot nguon thong tin tuyet voi .
# <  nhung la la la la la cua cua . . <EOS>
#
# > so i apos ve mentioned to you the four challenges .
# = va toi cung noi toi thach thuc .
# < vi vay toi toi ban mot e . . . <EOS>
#
# > this is what you see .
# =  o la ieu ban thay .
# <  ay la la la ban . <EOS>
#
# > and the fellow said quot absolutely nothing .
# = va nguoi o noi rang quot chac chan la khong co iem gi chung roi .
# < va cau la la la la quot quot . <EOS>
#
# > the point being that they apos ve developed cultural adaptation .
# =  iem mau chot o ay la chung a phat trien su thich nghi van hoa .
# <  la la chung la la la la <EOS>
#
# > it apos s surgically placed inside the inner ear .
# = no uoc at vao tai trong bang phuong phap phau thuat .
# < no la la la la la la . <EOS>
#
# > maybe i can use the other parts of my body to create extra sounds . quot
# = toi cung co the su dung nhung bo phan khac cua co the e tao ra am thanh .
# < toi co toi the the the quot nhung quot quot quot nhung quot quot quot quot . <EOS>
#
# > i would say quot would you die for him or her ? quot
# = toi noi rang quot ban co the chet vi anh ay hay co ay ? quot
# < toi noi quot quot quot quot quot quot quot quot quot quot ? <EOS>
#
# > according to scientists in years all the mountain glacier will be gone .
# = va theo nhieu nha khoa hoc trong vong nam tat ca moi song bang se bien mat .
# <  nguoi nhung nhung nhung nhung nhung nhung nhung nhung . <EOS>
#
# > a very small amount of money would get us some .
# = mot luong nho tien se lay cua chung ta mot so .
# < mot mot co mot co co co co co co . . <EOS>
#
# > this base has a lot of flaps in it .
# = phan tho nay co nhieu canh .
# <  ay la mot mot la la co . <EOS>
#
# > but this has a huge huge impact on the environment .
# = du an co mot tac ong khong lo toi moi truong .
# < nhung ay la mot mot la mot la mot <EOS>
#
# > now we might just as easily call these fears by a different name .
# = bay gio chung ta de dang co the goi nhung noi so o bang mot ten khac .
# ...
#
# > so pipa and sopa are round two .
# = vi the ma pipa va sopa la vong hai
# < vi la la la la la la . . <EOS>
#
# > and my interest in irrational behavior started many years ago in the hospital .
# = niem am me cua toi ve linh vuc nay bat au cach ay nhieu nam trong benh vien .
# < va nam nam nam nam nam nam nam nam nam nam nam nam nam <EOS>
#
# > so they learned quickly and efficiently .
# = ho a ghi nhan nhanh chong va hieu qua .
# < chung chung chung chung co va . . <EOS>
#
# > i really believe that .
# = toi that su tin vay .
# < toi toi la la . <EOS>
#
# >  quot kermit means nothing to me . quot
# =  quot kermit khong co y nghia gi oi voi toi . quot
# <  quot quot quot quot quot quot quot . quot .  <EOS>
#
# > the case went on for two years i think he apos s still appealing the case .
# = vu kien keo dai nam . toi nghi anh ta van ang theo kien
# <  nam toi toi toi toi toi toi toi toi toi toi toi . . <EOS>
#
# > it apos s really a question of scale .
# =  o thuc su la mot cau hoi ve quy mo .
# < no la la mot mot mot <EOS>
#
# > and they brought their knowledge .
# = va ho a mang en am phan su hieu biet cua ho .
# < va chung co co la . . <EOS>
#
# > greg stone saving the ocean one island at a time
# = greg stone cuu ai duong moi lan mot hon ao
# < mot mot la mot mot la mot <EOS>
#
# > ao a bit like this . dp like this . yes .
# = ao ai loai giong the nay . dp giong nhu the nay . ung roi .
# < mot mot la la . e . toi . . . . <EOS>
#
# > you know when we apos re going to get the results back ?
# = ban co biet khi nao thi chung ta se co ket qua khong ?
# < chung ta biet biet biet biet la la la <EOS>
#
# > and not only can they read them but they copy them .
# = va khong nhung nhan biet ho con sao chep chung .
# < va khong co khong khong chung co chung chung khong ho khong khong <EOS>
#
# > when they apos re out of education they do it on a computer .
# = khi hoc xong ho se lam toan tren may tinh .
# < khi ho chung chung chung chung chung chung . . <EOS>
#
# > and then i realized it was me you know and i kind of laughed .
# = va sau o toi nhan ra o la chinh toi ban biet khong va toi cuoi .
# < va toi toi no no toi no toi toi toi toi toi . toi . <EOS>
#
# > e yee haw .
# = e yee haw .
# < hay e . . <EOS>
#
# > thank you so much .
# = cam on cac ban .
# < cam on cac nhieu . <EOS>
#
# > in africa where i was i didn apos t have drinkable water .
# = o chau phi toi khong co nuoc sach e uong .
# < nhung nguoi toi toi toi toi toi la toi la . <EOS>
#
# > so is this just a story from south thailand ?
# =  ay chi la cau chuyen tu mien nam thai lan u ?
# <  ay la la mot la la mot la <EOS>
#
# > those are pretty good escapes from the drab weather in switzerland .
# = la nhung thu kha tot ngoai thoi tiet u am o thuy si .
# <  o la la la la la trong la la trong <EOS>
#
# > they apos ve kidded out the house with cctv cameras .
# = ho lap camera giam sat ay nha .
# < ho la la nhung nhung . . . . . <EOS>
#
# > and here is a new park in lower manhattan .
# = con ay la mot cong vien moi o ha manhattan .
# < va ay la mot la la . . <EOS>
#
# > and now this next clip is just eight minutes later .
# = va trong clip ke tiep la chi phut sau o .
# < va ay nay la la la la la la . . <EOS>
#
# > well it apos s got to do with your brain .
# = boi vi ieu o co lien quan toi bo nao cua ban .
# < no no la la e e e . . <EOS>
#
# > keith schacht now be sure and take the two pieces apart .
# = keith schact gio thi dut khoat keo hai manh ra khoi nhau nhe .
# < hay gio nay nay nay va la va va va va . <EOS>
#
# > so what do we need ?
# = vay chung toi can gi ?
# < vay chung chung ta chung ta ? <EOS>
#
# > so this is the sketch of the two states .
# = va ay la ban phac cua trang thai .
# <  ay la la la la cua cua cua . <EOS>
#
# > one two three . one two three . one two three .
# = mot hai ba . mot hai ba . mot hai ba .
# < mot mot mot mot mot mot . . . . <EOS>
#
# > i am in charge of making this country apos s food secure .
# = toi chiu trach nhiem am bao nguon luong thuc cho at nuoc nay .
# < toi a la trong cua cua cua la cua . . <EOS>
#
# > more than percent of the population lives below the federal poverty line .
# = hon phan tram dan so song trong canh ngheo oi .
# < nhung nguoi nhung hon la hon hon hon hon la hon <EOS>
#
# > but the fact is we do know a lot about all of those things .
# = nhung su thuc la chung ta biet rat nhieu ve nhung thu o
# < nhung nhung chung chung chung ta chung ta ta chung ta la la <EOS>
#
# > these are the boom and bust refugees .
# = ho la nhung ke ti nan bung no va tan vo boom and burst .
# <  ay la la va va va <EOS>
#
# > they might some place out there .
# = chung co the o au o ngoai kia .
# < ho co co nhung co nhung . <EOS>
#
# > thank you very much . thank you .
# = cam on cac ban rat nhieu . xin cam on .
# < cam on on . ban . ban . . <EOS>
#
# > these are when .
# = va thoi iem
# <  o la la . <EOS>
#
# > i get emotional . sorry .
# = toi qua xuc ong roi . xin loi .
# < toi a . . . . . <EOS>
#
# > she said quot yes i did .
# = ba noi quot phai tao a lam the ay
# < co quot quot toi toi quot quot .  <EOS>
#
# > the world has a new mania .
# = the gioi co mot hoi chung cuong tin moi .
# <  nguoi co la la la la <EOS>
#
# > and i would hold immediately after for five and half minutes .
# = va toi giu ngay lap tuc sau o trong nam phut va giay .
# < va toi a la va va va va va va . <EOS>
#
# > and at some point of its life it implants on a rock .
# = va vao mot thoi iem nao o trong cuoc song cua minh hai tieu bam vao a .
# < va mot la mot la mot la la su mot . <EOS>
#
# > and my hope is that some of you out there may be able to help us .
# = va toi hy vong rang vai nguoi trong cac ban o ay co the giup uoc chung toi .
# < va co co la co co co nhung co co co co co co the nhung <EOS>
#
# > so for example rats are incredibly responsive breeders .
# = the vi du nhe chuot e con vo cung nhanh nhay .
# < vi vi la la la la la la la <EOS>
#
# > we apos re very afraid .
# = chung ta rat so .
# < chung ta la . . <EOS>
#
# > pretty good . and at school ?
# = o cung kha ay chu ? con o trung hoc thi sao a ?
# <  au la va va <EOS>
#
# > but i never became a designer . no no no no . never attempted . never even close .
# = nhung toi chua bao gio thu lam nha thiet ke . khong khong va khong bao gio .
# < nhung toi khong khong khong khong khong khong khong khong khong khong khong khong khong khong khong . . <EOS>
#
# > you cannot oppress the people who are not afraid anymore .
# = ban khong the an ap nhung nguoi khong con thay so nua .
# < ban co co co co co khong co khong khong khong <EOS>
#
# > this is the christmas message from nico .
# =  ay la tin nhan giang sinh tu nico .
# <  ay la la la la la . . <EOS>
#
# > the other in nuances .
# = con truyen hu cau tao ra nhung khac biet tinh te
# <  thu la la . <EOS>
#
# > my job isn apos t to think of those .
# = cong viec cua toi khong phai la nghi en chung
# < nhung toi khong khong nghi la la la . <EOS>
#
# > we know and expect that we apos ll see that .
# = chung ta mong oi se biet uoc nhung thong tin o .
# < chung ta chung chung chung chung chung chung la chung . <EOS>
#
# > here is one example . this is a train which goes from london to paris .
# =  ay la vi du . ay la con tau i tu london toi paris .
# <  ay la mot la mot mot la mot mot la mot mot <EOS>
#
# > the second project i want to talk to you about is the thylacine project .
# = du an thu hai ma toi muon noi en la du an thu co tui
# < hay nghi toi toi nghi la e e e e e e e e <EOS>
#
# > but sometimes it apos s very paradoxical .
# = nhung thinh thoang rat nguoc oi .
# < nhung no no no co . <EOS>
#
# > our world is defined by the pace of change .
# = the gioi chung ta uoc inh nghia bang toc o cua su bien chuyen .
# < nhung co la la la la la nhung cua nhung <EOS>
#
# > boeing sent me a in containers .
# = boeing gui cho toi chiec goi trong cac container
# <  toi toi toi mot mot . <EOS>
#
# > i want it to keep flying .
# = toi muon van e no bay .
# < toi muon muon . . . . . . <EOS>
#
# > jesus watches what you do . pray to him . quot
# = chua giesu biet bo lam gi . hay cau nguyen voi ngai . quot
# < hay thu thu ban . toi . quot . . . . . <EOS>
#
# > now the next step try this .
# = gio buoc tiep theo hay thu no .
# < gio gio nay nay nay la nay <EOS>
#
# > and each gene gives us a fingerprint .
# = va moi gene cho chung ta mot dau van tay .
# < va co la la la la la mot <EOS>
#
# > we have almost million roots .
# = chung ta thay co gan trieu re .
# < chung ta co co co nhieu <EOS>
#
# > there apos s a fish with glowing eyes pulsating eyes .
# =  ay la mot con ca voi oi mat nhap nhay ruc ro .
# < co mot mot mot mot co mot . . <EOS>
#
# > i talk about myself . that apos s what i am . i apos m a blogger .
# = toi noi ve ban than . o la con nguoi toi . toi la mot nguoi viet blog .
# < toi nghi la toi la toi toi la toi toi toi toi toi . . <EOS>
#
# > it tries to balance out and that apos s just .
# = viec o lam can bang cho nen la hop le .
# < no no la va va va va va . <EOS>
#
# > the team is proud of our four attempts .
# =  oi ngu tu hao ve bon lan no luc cua chung toi .
# <  la la la la la cua cua <EOS>
#
# > so inertia versus momentum .
# = vi vay suc i au voi suc ay .
# < vi nen la . . . . <EOS>
#
# > and okay i wouldn apos t change it .
# = va uoc roi toi se khong thay oi no au .
# < va toi khong khong khong khong . . . <EOS>
#
# > sometimes you get very very severe queues .
# =  oi khi ban phai xep hang cho rat rat lau .
# <  ban ban ban ban ban ban . . <EOS>
#
# > but that apos s what happened all over eastern europe .
# = tuy nhien o la nhung gi xay ra o khap ong au .
# < nhung no o la nhung gi gi gi gi <EOS>
#
# > in fact we actually have the printer right here .
# = tren thuc te chung toi co mang chiec may o en ay .
# < nhung chung chung chung ta chung ta la la <EOS>
#
# > what i think i apos ve been talking about really is success and failure .
# = toi nghi toi thuc su noi en la thanh cong va that bai .
# < nhung toi nghi la la la la la la la la la <EOS>
#
# > i could do this all day every day and i can apos t keep up .
# = hang ngay toi co the lam cong viec nay ca ngay nhung khong the duy tri .
# < toi co the the nhung co the nhung va va co va the <EOS>
#
# > we said quot well what do tails do ? quot
# = chung toi noi quot o uoi lam cai gi nhi ? quot
# < chung ta quot quot quot quot quot gi quot quot    <EOS>
#
# > thank you .
# = cam on
# < cam on . . <EOS>
#
# > all they had was mike apos s hard lemonade which was five percent alcohol .
# = ca nhung gi nguoi ta co la nuoc chanh mike apos s hard co chua con .
# < ho co chung la la la la nguoi nhung nguoi nhung <EOS>
#
# > you do not have to teach someone how to drive romo .
# = ban khong phai day ai o cach e lai romo .
# < co co phai phai phai co co e nhung e e . <EOS>
#
# > don apos t waste computer cycles .
# =  ung lang phi chu ky cua may tinh .
# <  khong la la . . <EOS>
#
# > why don apos t they affect me ?
# = tai sao chung khong anh huong toi toi ?
# < tai sao khong khong khong ? ? ? <EOS>
#
# > and that does not even include those that are trafficked within country borders which is a substantial portion .
# =  o la chua tinh so bi ua lau trong lanh tho moi nuoc cung la so luong lon
# < va no la la la la la la la la la la la la co la <EOS>
#
# > this affected my entire body .
# =  ieu nay anh huong en toan bo co the toi .
# <  au la la la la . <EOS>
#
# > how attractive are you ?
# = ban cuon hut nhu the nao ?
# < nhung co ban ban ? ? ? <EOS>
#
# > what they got exactly wrong was what happens next .
# = nhung chung sai ve nhung gi tiep theo .
# < nhung co co nhung nhung la nhung nhung nhung nhung . <EOS>
#
# > why is that ?
# = vi sao lai nhu the ?
# < tai sao la ? ? ? <EOS>
#
# > it apos s actually the exact opposite .
# =  oi lap hoan toan so voi binh thuong .
# < no la la la la . <EOS>
#
# > the problem with concepts of trust and cooperation is that they are feelings they are not instructions .
# = van e la tin tuong va hop tac la nhung cam xuc khong phai menh lenh .
# < khong la la la la la va la va va la va va khong <EOS>
#
# > and i think the message of this is very clear .
# = toi nghi thong iep rat ro rang .
# < va toi nghi la mot la la la e <EOS>
#
# > and i began to start teaching there .
# = va toi bat au day hoc o o .
# < va toi a la nguoi nguoi . <EOS>
#
# > the bottom one ? yellow .
# = con o ben duoi ? mau vang
# <  la la la . <EOS>
#
# > so when it apos s quiet it apos s sort of coming out from behind the panels .
# = khi khong gian im lang thi chung bat au chui ra khoi tam pano .
# < vi la la la la la la la la la la la . <EOS>
#
# > students family and friends all read me material .
# = cac sinh vien gia inh va ban be eu oc tai lieu cho toi nghe .
# <  va va va va va va va . . <EOS>
#
# > and plato he had a lot of the same concerns that we did .
# = va plato ong ta co nhieu moi quan tam nhu chung ta co .
# < va chung ta ta chung ta ta ta ta ta ta ta <EOS>
#
# > and it actually drove up our yields .
# = va no thuc su giup tang san luong cho chung ta .
# < va no la la su su su . . <EOS>
#
# > thank you .
# = cam on cac ban .
# < cam on . . <EOS>
#
# > sexually attractive people are hot .
# = nhung nguoi quyen ru thi nong bong .
# < nhung nguoi co nguoi la la la <EOS>
#
# > there apos s something terrible happening . quot
# = at han co chuyen gi te hai ang xay ra . quot
# < co co quot quot quot .  <EOS>
#
# > sorry about that if i startled anybody .
# = xin loi neu toi lam ai o giat minh .
# <  o toi toi toi toi toi . . <EOS>
#
# > and he called the two of them to his office .
# = va ong ta goi hai nguoi vao phong cua ong ta .
# < va ay la la la e e e . . . <EOS>
#
# > as we know our feelings about how we apos re feeling are notoriously unreliable .
# = nhu chung ta biet cam nhan ve cam xuc nhat thoi la cuc ky khong ang tin .
# < chung chung ta chung ta chung ta chung ta chung ta chung ta nhung <EOS>
#
# > it just seems to me possibly even a blank page would have been more appropriate .
# = thuc su ma noi mot trang trang o o thi a phu hop hon nhieu lam .
# < no co la phai la co mot e mot e mot e mot . . <EOS>
#
# > but japan proved that trying to resist the force of nature is useless .
# = nhung nhat ban a chung minh rang co gang chong lai tu nhien la vo ich .
# < nhung nhung co la la la la la la la la nhung <EOS>
#
# > and this is just one of a number of mines mines so far right now .
# = va ay chi la mot trong nhieu mo tinh en bay gio la mo .
# < va ay la mot mot mot mot co mot co mot co nhieu . <EOS>
#
# > but there apos s also a certain beauty within this technology .
# = no con co mot ieu thu vi nua voi cong nghe nay
# < nhung co co nhung co mot nhung nhung nhung <EOS>
#
# > now that is pretty authoritarian and that apos s something i apos m very much critical of .
# = bay gio ieu o kha la oc oan va la ieu toi muon phe phan .
# <  ay la la va va la va va la va la va <EOS>
#
# > we produced great artists . beckett is our muse .
# = chung toi cung ao tao ra nhieu nghe si . beckett la mot trong so o
# < chung ta chung chung chung la la . . . . <EOS>
#
# > while he was there i tried to impress him of course .
# = trong khi ong ta o o toi co gang tao an tuong voi ong di nhien .
# < co ay toi toi toi toi toi toi co . . <EOS>
#
# > i always landed like a watermelon out of a third floor window .
# = toi luon ha canh giong nhu mot qua dua hau roi tu cua so tang .
# < toi nghi la mot mot mot mot mot mot mot <EOS>
#
# > supply demand big opportunity .
# = cung cau co hoi lon .
# < hay e la mot ve . <EOS>
#
# > it primes you to do things that strengthen close relationships .
# = no chi dan ban lam nhung ieu e that chat hon cac moi quan he .
# < no ieu ban ban no ban ban ban ban ban . <EOS>
#
# > if you look at the current situation you have a thousand tedtalks .
# = ban co the thay tinh hinh la ban co cuoc noi chuyen ted .
# < neu co co ban ban ban ban ban ban ban ban . <EOS>
#
# > one way trips are easy .
# =  i mot chieu rat on gian .
# < mot thu la la la . <EOS>
#
# > i hadn apos t swum for years not a stroke .
# = toi a khong boi trong nam khong boi lay mot sai .
# < toi khong la la mot la . . . <EOS>
#
# > well the brain as you know is made up of neurons .
# = vang bo nao nhu cac ban biet ay cau tao tu cac no ron .
# < khong nhung la ban ban ban ban la la ban ban <EOS>
#
# > i don apos t think we can afford too much of such ethical choices .
# = toi khong nghi chung ta co the tra noi cho nhung lua chon ao uc nhu the .
# < chung ta khong nghi chung ta the co the co the co <EOS>
#
# > and i decided that i was going to go to school . so i did .
# = va toi quyet inh rang toi se i hoc lai . va toi a lam vay .
# < va toi toi toi no toi toi toi toi e . . . . . <EOS>

# %%
# !python -v

# %%
# %matplotlib inline

# %%
# import matplotlib.pyplot as plt
# plt.switch_backend('agg')
# import matplotlib.ticker as ticker
# import numpy as np

# %%
output_words, attentions = evaluate(
    encoder1, attn_decoder1, "so the sweet spot is between and .")
plt.matshow(attentions.numpy())

# %%
plt.show()

# %%
def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()


def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions)


evaluateAndShowAttention( "so the sweet spot is between and .")
# Out:
# input = so the sweet spot is between and .
# output = toi toi toi <EOS>

# %%
# plt.show()

# %%
print(attentions.numpy())
# Out:
# [[0.06650251 0.10301824 0.07508122 0.05581292 0.02509947 0.04413332
#   0.03431515 0.03588856 0.05438361 0.02905324 0.04494955 0.0439374
#   0.03799711 0.03076176 0.04737048 0.0375242  0.03703386 0.05631624
#   0.10528323 0.0355379 ]
#  [0.04690807 0.01246079 0.0328928  0.05447211 0.08733529 0.04843982
#   0.03746487 0.05340164 0.07851356 0.04202087 0.05615489 0.06893636
#   0.02311224 0.04497547 0.04227775 0.0761739  0.04522978 0.06044141
#   0.02584803 0.06294037]
#  [0.05108525 0.01560705 0.03408435 0.04091396 0.0717079  0.05068386
#   0.04169271 0.05785382 0.07935688 0.04017191 0.06448099 0.05991703
#   0.02715822 0.02709745 0.04867249 0.07404753 0.02829073 0.09049004
#   0.03196885 0.06471904]
#  [0.04525953 0.01254695 0.030343   0.04443931 0.08730087 0.05167755
#   0.04357855 0.05073893 0.07833032 0.04787146 0.06180573 0.05754629
#   0.02306538 0.04450263 0.03926876 0.08829272 0.04412698 0.06810462
#   0.02723201 0.05396841]]

# %%
plt.matshow(attentions.numpy())

# %% [markdown]
# 1. BiLSTM
# 2. GloVE embedding
# 3. presentation
# 4. BLUE Score and how error is calculated here
# 5.
